# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dgTest = pd.read_csv('test_labels.csv')
dgTrain = pd.read_csv('train_labels.csv')

# %%
count_diagnosis_test = dgTest['diagnosis'].value_counts().sort_index()

cores = plt.cm.Reds(np.linspace(0.2, 1, 5)) 
count_diagnosis_test.plot(kind='bar', color=cores)

plt.title('Classificação das imagens analisadas labels_test')
plt.xlabel('Classificação')
plt.ylabel('Quantidade de imagens')

niveis_dr = ['Não possui RD', 'Leve', 'Moderada', 'Severa', 'RD Proliferativa']

plt.xticks(range(len(niveis_dr)), niveis_dr, rotation='horizontal')
# Out:
# ([<matplotlib.axis.XTick at 0x231b5f19dc0>,
# ...
#  [Text(0, 0, 'Não possui RD'),
#   Text(1, 0, 'Leve'),
#   Text(2, 0, 'Moderada'),
#   Text(3, 0, 'Severa'),
#   Text(4, 0, 'RD Proliferativa')])

# %%
plt.show()

# %%
count_diagnosis_train = dgTrain['diagnosis'].value_counts().sort_index()

count_diagnosis_train.plot(kind='bar', color=cores)

plt.title('Classificação das imagens analisadas labels_train')
plt.xlabel('Classificação')
plt.ylabel('Quantidade de imagens')

niveis_dr = ['Não possui RD', 'Leve', 'Moderada', 'Severa', 'RD Proliferativa']

plt.xticks(range(len(niveis_dr)), niveis_dr, rotation='horizontal')
# Out:
# ([<matplotlib.axis.XTick at 0x231b5b8fd10>,
# ...
#  [Text(0, 0, 'Não possui RD'),
#   Text(1, 0, 'Leve'),
#   Text(2, 0, 'Moderada'),
#   Text(3, 0, 'Severa'),
#   Text(4, 0, 'RD Proliferativa')])
