# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
dgA = pd.read_csv('archives_data/B. Disease Grading/2. Groundtruths/a. IDRiD_Disease Grading_Training Labels.csv')

# %%
dgB = pd.read_csv('archives_data/B. Disease Grading/2. Groundtruths/b. IDRiD_Disease Grading_Testing Labels.csv')

# %%
#EXCLUIR COLUNAS VAZIAS

# Remover as colunas a partir da 4 coluna
dgA = dgA.iloc[:, :3]

# %%
dgAB = pd.concat([dgA, dgB])

# %%
count_diagnosis_test = dgAB['Retinopathy grade'].value_counts().sort_index()

cores = plt.cm.Reds(np.linspace(0.2, 1, 5)) 
count_diagnosis_test.plot(kind='bar', color=cores)

plt.title('Classificação das imagens analisadas Indian')
plt.xlabel('Classificação')
plt.ylabel('Quantidade de imagens')

niveis_dr = ['Não possui RD', 'Leve', 'Moderada', 'Severa', 'RD Proliferativa']

plt.xticks(range(len(niveis_dr)), niveis_dr, rotation='horizontal')
# Out:
# ([<matplotlib.axis.XTick at 0x27eb7b678c0>,
# ...
#  [Text(0, 0, 'Não possui RD'),
#   Text(1, 0, 'Leve'),
#   Text(2, 0, 'Moderada'),
#   Text(3, 0, 'Severa'),
#   Text(4, 0, 'RD Proliferativa')])

# %%
count_diagnosis_test = dgAB['Risk of macular edema '].value_counts().sort_index()

count_diagnosis_test.plot(kind='bar', color=['green', 'yellow', 'red'])

plt.title('Risco de edema macular das imagens analisadas Indian')
plt.xlabel('Classificação')
plt.ylabel('Quantidade de imagens')

risco_edema = ['Baixo', 'Médio', 'Alto']

plt.xticks(range(len(risco_edema)), risco_edema, rotation='horizontal')
# Out:
# ([<matplotlib.axis.XTick at 0x27eb7c029c0>,
# ...
#  [Text(0, 0, 'Baixo'), Text(1, 0, 'Médio'), Text(2, 0, 'Alto')])

# %%
dtOpticA = pd.read_csv('archives_data/C. Localization/2. Groundtruths/1. Optic Disc Center Location/a. IDRiD_OD_Center_Training Set_Markups.csv');

# %%
dtOpticB = pd.read_csv('archives_data/C. Localization/2. Groundtruths/1. Optic Disc Center Location/b. IDRiD_OD_Center_Testing Set_Markups.csv')

# %%
OpticFilterA = dtOpticA.iloc[:413, :3]

# %%
OpticFilterB = dtOpticB.iloc[:103, :3]

# %%
OpticData = pd.concat([OpticFilterA, OpticFilterB], ignore_index=True)

# %%
plt.figure(figsize=(10, 6))

plt.scatter(OpticData['X- Coordinate'], OpticData['Y - Coordinate'], alpha=0.6, edgecolors='w', s=100)

plt.title('Distribuição das Coordenadas do Disco Optico')
plt.xlabel('Coordenada X')
plt.ylabel('Coordenada Y')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(x=OpticData['X- Coordinate'], y=OpticData['Y - Coordinate'], cmap="Reds", fill=True, thresh=0.05)

plt.title('Mapa de Calor das Coordenadas do Disco Optico')
plt.xlabel('Coordenada X')
plt.ylabel('Coordenada Y')

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.hexbin(OpticData['X- Coordinate'], OpticData['Y - Coordinate'], gridsize=30, cmap='Reds')

plt.colorbar(label='Contagem')


plt.title('Histograma 2D das Coordenadas do Disco Optico')
plt.xlabel('Coordenada X')
plt.ylabel('Coordenada Y')

plt.show()

# %%
dtFoveaA = pd.read_csv('archives_data/C. Localization/2. Groundtruths/2. Fovea Center Location/IDRiD_Fovea_Center_Testing Set_Markups.csv')

# %%
dtFoveaA = dtFoveaA.iloc[:103, :3]

# %%
dtFoveaB = pd.read_csv('archives_data/C. Localization/2. Groundtruths/2. Fovea Center Location/IDRiD_Fovea_Center_Training Set_Markups.csv')

# %%
dtFoveaB = dtFoveaB.iloc[:413, :3]

# %%
dtFovea = pd.concat([dtFoveaA, dtFoveaB])

# %%
plt.figure(figsize=(10, 6))

plt.scatter(dtFovea['X- Coordinate'], dtFovea['Y - Coordinate'], alpha=0.6, edgecolors='w', s=100)

plt.title('Distribuição das Coordenadas Regiao central Fovea')
plt.xlabel('Coordenada X')
plt.ylabel('Coordenada Y')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(x=dtFovea['X- Coordinate'], y=dtFovea['Y - Coordinate'], cmap="Reds", fill=True, thresh=0.05)

plt.title('Mapa de Calor das Coordenadas da Regiao Central Fovea')
plt.xlabel('Coordenada X')
plt.ylabel('Coordenada Y')

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.hexbin(dtFovea['X- Coordinate'], dtFovea['Y - Coordinate'], gridsize=30, cmap='Reds')

plt.colorbar(label='Contagem')


plt.title('Histograma 2D das Coordenadas da Regiao central Fovea')
plt.xlabel('Coordenada X')
plt.ylabel('Coordenada Y')

plt.show()

# %%
# Gráfico de dispersão para o disco óptico
plt.figure(figsize=(12, 6))



plt.subplot(1, 2, 1)
plt.scatter(OpticData['X- Coordinate'], OpticData['Y - Coordinate'], color='blue', label='Disco Óptico', alpha=0.6)
plt.title('Distribuição das Coordenadas do Disco Óptico')
plt.xlabel('Coordenada X')
plt.ylabel('Coordenada Y')
plt.legend()

# Gráfico de dispersão para a fóvea
plt.subplot(1, 2, 2)
plt.scatter(dtFovea['X- Coordinate'], dtFovea['Y - Coordinate'], color='red', label='Fóvea', alpha=0.6)
plt.title('Distribuição das Coordenadas da Fóvea')
plt.xlabel('Coordenada X')
plt.ylabel('Coordenada Y')
plt.legend()

plt.show()

# %%
dgAB.rename(columns={'Image name': 'Image No'}, inplace=True)

# %%
dados_mesclados = OpticData.merge(dtFovea, on='Image No').merge(dgAB, on='Image No')

# %%
dados_mesclados.rename(columns={'X- Coordinate_x': 'opticX', 'Y - Coordinate_x': 'opticY'}, inplace=True)
dados_mesclados.rename(columns={'X- Coordinate_y': 'foveaX', 'Y - Coordinate_y': 'foveaY'}, inplace=True)
dados_mesclados.rename(columns={'Retinopathy grade': 'grade', 'Risk of macular edema ': 'risk'}, inplace=True)

# %%
# Definir uma paleta de cores de vermelho claro a vermelho escuro
paleta = plt.cm.Reds(np.linspace(0.3, 1, 5))

# Gráfico de dispersão das coordenadas com classificação e risco
plt.figure(figsize=(12, 6))

# Disco Óptico
plt.subplot(1, 2, 1)
scatter = plt.scatter(dados_mesclados['opticX'], dados_mesclados['opticY'],
                      c=dados_mesclados['grade'], cmap=plt.cm.Reds, alpha=0.6,
                      s=(dados_mesclados['risk'] + 1) * 20, edgecolors='w')
plt.title('Disco Óptico - Classificação e Risco de Edema')
plt.xlabel('Coordenada X do Disco Óptico')
plt.ylabel('Coordenada Y do Disco Óptico')
cbar = plt.colorbar(scatter, ticks=[0, 1, 2, 3, 4])
cbar.set_label('Classificação da Retinopatia')
cbar.set_ticks([0, 1, 2, 3, 4])
cbar.set_ticklabels(['0', '1', '2', '3', '4'])
plt.legend(*scatter.legend_elements("sizes", num=3), title='Risco de Edema')

# Fóvea
plt.subplot(1, 2, 2)
scatter = plt.scatter(dados_mesclados['foveaX'], dados_mesclados['foveaY'],
                      c=dados_mesclados['grade'], cmap=plt.cm.Reds, alpha=0.6,
                      s=(dados_mesclados['risk'] + 1) * 20, edgecolors='w')
plt.title('Fóvea - Classificação e Risco de Edema')
plt.xlabel('Coordenada X da Fóvea')
plt.ylabel('Coordenada Y da Fóvea')
cbar = plt.colorbar(scatter, ticks=[0, 1, 2, 3, 4])
cbar.set_label('Classificação da Retinopatia')
cbar.set_ticks([0, 1, 2, 3, 4])
cbar.set_ticklabels(['0', '1', '2', '3', '4'])
plt.legend(*scatter.legend_elements("sizes", num=3), title='Risco de Edema')

plt.tight_layout()
plt.show()

# %%
# Criar uma tabela resumo
tabela_resumo = dados_mesclados.groupby(['grade', 'risk']).agg({
    'opticX': 'mean',
    'opticY': 'mean',
    'foveaX': 'mean',
    'foveaY': 'mean'
}).reset_index()

print(tabela_resumo)
# Out:
#     grade  risk       opticX       opticY       foveaX       foveaY
# 0       0     0  1851.118519  1393.966667  2000.692593  1546.044444
# 1       1     0  1910.021739  1399.652174  1911.913043  1531.804348
# 2       2     0  1898.750000  1367.142857  1906.821429  1495.214286
# 3       2     1  1914.541667  1388.750000  2004.152778  1534.527778
# 4       2     2  1953.738411  1386.152318  1970.049669  1535.149007
# 5       3     0  2150.523810  1331.952381  1849.428571  1479.904762
# 6       3     1  1522.045455  1367.136364  2011.545455  1519.590909
# 7       3     2  2037.622340  1396.925532  1958.494681  1530.904255
# 8       4     0  2001.571429  1395.357143  2021.785714  1529.642857
# 9       4     1  2137.187500  1367.812500  1816.500000  1449.000000
# 10      4     2  1760.296000  1366.384000  1997.448000  1506.512000
